# %%
#1. Create a list named students with 5 student names and print it.
students=["mahi","shweta","vidhya","akanksha","dvitiya"]
print(students)
# Out:
# ['mahi', 'shweta', 'vidhya', 'akanksha', 'dvitiya']

# %%
#2. Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().
numbers=[10,20,30,40,50]
print(type(numbers))

print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
#3. Create an empty list and append 3 numbers into it using append().
list3=[25,6,7,2,3,445]
add=[34,56,78]
list3.append(add)
print(list3)
# Out:
# [25, 6, 7, 2, 3, 445, [34, 56, 78]]

# %%
#4. Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.

lst=[1,2,3]
add1=[4,5,6]
lst.extend(add1)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#5. Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].
list=[10,20,30,40]
list.insert(2,100)
print(list)
# Out:
# [10, 20, 100, 30, 40]

# %%
#6. Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().

List=[10, 20, 50, 30, 50]
List.remove(50)
print(List)
# Out:
# [10, 20, 30, 50]

# %%
#7. Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.
Lst = [5, 10, 15, 20]
Lst.pop()
print(Lst)
# Out:
# [5, 10, 15]

# %%
#8. Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().

data = [1, 2, 3, 4, 5]
data.clear()
print(data)
# Out:
# []

# %%
#9. Find the index of 25 in the list [10, 15, 25, 30, 40] using index().
l_ist=[10,15,25,30,40]
print(l_ist.index(25))
# Out:
# 2

# %%
#10. Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count().

List=[7,2,7,5,7,8]
print(List.count(7))
# Out:
# 3

# %%
#11. Sort the list [45, 12, 78, 23, 56] in ascending order using sort().
List11=[45,12,78,23,56]
List11.sort()
print(List11)
# Out:
# [12, 23, 45, 56, 78]

# %%
#12. Sort the  list [45, 12, 78, 23, 56] in descending order.
list12= [45, 12, 78, 23, 56]
list12.sort(reverse=True)
print(list12)
# Out:
# [78, 56, 45, 23, 12]

# %%
#13. Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse().
fruits=["apple", "banana", "mango", "orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
#14. Create a copy of list original = [1, 2, 3, 4] using copy() and print both.
original = [1, 2, 3, 4] 
ori=original.copy()
print(original)
print(ori)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
#15. Take a sentence from user (e.g. "I love Python programming") and convert it into a list of words using split().
sent=input("Enter the sentence")
print(sent)
sent1=sent.split()
print(sent1)
# Out:
# Enter the sentence hey this is the google cloud for storing the data
# hey this is the google cloud for storing the data
# ['hey', 'this', 'is', 'the', 'google', 'cloud', 'for', 'storing', 'the', 'data']

# %%
#16. Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order.
LIS_T=[23,45,67,89,00]
add=[10,23,45]


LIS_T.sort(reverse=True)
print(LIS_T)

LIS_T.append(add)
print(LIS_T)
# Out:
# [89, 67, 45, 23, 0]
# [89, 67, 45, 23, 0, [10, 23, 45]]

# %%
#17. Create a list. Insert "Python" at index 0, then remove the last element using pop(), and print the length.

Name=["this","is","python","programming"]
Name.insert(0,"pyhton")
print(Name)

Name.pop()
print(Name)

print(len(Name))
# Out:
# ['pyhton', 'this', 'is', 'python', 'programming']
# ['pyhton', 'this', 'is', 'python']
# 4

# %%
#18. Take 5 city names as input from user and store them in a list. Then print them in reverse order.
city1=input("enter the city name")
city2=input("enter the city name")
city3=input("enter the city name")
city4=input("enter the city name")
city5=input("enter the city name")

List=[city1,city2,city3,city4,city5]
print(List)

List.reverse()
print(List)
# Out:
# enter the city name nanded
# enter the city name pune
# enter the city name nagpur
# enter the city name delhi
# enter the city name hyd
# ['nanded', 'pune', 'nagpur', 'delhi', 'hyd']
# ['hyd', 'delhi', 'nagpur', 'pune', 'nanded']

# %%
#19. Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20 (use loop or multiple remove).

data = [10, 20, 30, 20, 40, 20]
for i in data:
    i=20
    data.remove(20)

print(data)
# Out:
# [10, 30, 40]

# %%
#20. Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.

student_marks=[34,55,66,90,99,100,25,77,87,98,99.9]

student_marks.sort()
print(student_marks)


print("the lowest student marks are: ",student_marks[0])
print("the highest student are: ",student_marks[10])
# Out:
# [25, 34, 55, 66, 77, 87, 90, 98, 99, 99.9, 100]
# the lowest student marks are:  25
# the highest student are:  100
