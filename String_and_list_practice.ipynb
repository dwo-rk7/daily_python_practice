# %%
#1 take a string from the user and replace all spaces with underscore using replace() method
name=input("enter your fullname name:" )
print(name)
name=name.replace(" ","_")
print(name)
# Out:
# enter your fullname name: hgf
# hgf
# hgf

# %%
#2 take any string and remove leading and trailing spaces using strip()
string2="       spacess        "
string2
string2=string2.strip()
string2
# Out:
# 'spacess'

# %%
#3 take a sentence and check weather it starts with "hello" using starts with()
string3="hello this is the python programming language"
string3
string3=string3.startswith("hello")
print(string3)
# Out:
# True

# %%
#4 take a stringand check if it ends with ".com"using endswith()
string4="anc23456@gamil.com"
string4
string4=string4.endswith(".com")
print(string4)
# Out:
# True

# %%
#5 take a comm_seperated string like "apple,banana,mango" and split it using split()
string5=("apple,banana,choclate,potato")

string5=string5.split(',')
print(string5)
# Out:
# ['apple', 'banana', 'choclate', 'potato']

# %%
#6Create a list of 5 fruits and join them using space " " with join().
list1=("kiwi,apple,banana,plum,dragonfruit")
list1
list1=(" ".join(list1))
print(list1)
# Out:
# k i w i , a p p l e , b a n a n a , p l u m , d r a g o n f r u i t

# %%
#7Create a list: [" Python ", " is ", " awesome "]. Strip each word and join them.

list2=["pyhton  ","is   ","  awesome  "]

#strip
list2[0] = list2[0].strip()
list2[1] = list2[1].strip()
list2[2] = list2[2].strip()
list2

#join
list2=("-".join(list2))
list2
# Out:
# 'pyhton is awesome'

# %%
#8Take a full name (e.g. "Rahul Kumar Sharma") and print only first and last name using split().

name="vaishnavi navnath kirkan"
name=name.split(" ")
print(name)
# Out:
# ['vaishnavi', 'navnath', 'kirkan']

# %%
#9 take a sentence from the user ,split it into words and print the total number of words
sent=input("enter a sentence:   ")

sent=sent.split(" ")
print(sent)

sent=len(sent)
print(sent)
# Out:
# enter a sentence hii this is
# ['hii', 'this', 'is', '']
# 4

# %%
#10Take an email address and check if it ends with "@gmail.com" using endswith()
email="asdfg23456@gmail.com"
email
email=email.endswith("@gmail.com")
email
# Out:
# True

# %%
#11 Take a string "Hello World Python" . Replace "World" with "Everyone" and then split the result
string11="hello world python"
string11

#replace
string11=string11.replace("world","everyone")
string11

#split
string11=string11.split()
string11
# Out:
# ['hello', 'everyone', 'python']

# %%
#12 Create a list of 5 city names from user input. Join them with new line "\n" and print.
city1=input("enter the city name ")
city2=input("enter the city name ")
city3=input("enter the city name ")
city4=input("enter the city name ")
city5=input("enter the city name ")
cities=(city1,city2,city3,city4,city5)
cities="\n ".join(cities)
cities
# Out:
# enter the city name  s
# enter the city name  d
# enter the city name  f
# enter the city name  g
# enter the city name  h
# 's\n d\n f\n g\n h'

# %%
#13 Take a string " hello world ". Strip it, convert to title case, and check if it starts with "Hello"
string13="         hello world"
string13
#strip
string13=string13.strip(" ")
string13
#title
string13=string13.title()
string13
#startwith
string13=string13.startswith("hello")
string13
# Out:
# False

# %%
#14 Take a sentence and replace the word "bad" with "good" after splitting and joining.
sent2="the bad apple is the good apple"
sent2
#spilt
sent2=sent2.split(" ")
sent2
#join
sent2=(" ".join(sent2))
sent2
#replace
sent2=sent2.replace("bad","good")
sent2
# Out:
# 'the good apple is the good apple'

# %%
#15 (Medium) Take a list ["10", "20", "30", "40"] and join them with "-" using join().
list3=["10","20","30","40"]
list3
list3=("-".join(list3))
list3
# Out:
# '10-20-30-40'

# %%
#16  Take a sentence. Split into words, remove all words that start with vowel (a,e,i,o,u), then join remaining words.
string16="hey good morning this is vaishnavi kirkan "
string16

#split
string16=string16.split("\n")
print(string16)

#replace
#string16.remove()*(string16.startswith("aeiou")
# Out:
# ['hey good morning this is vaishnavi kirkan ']

# %%
#17  Take a string. Replace all spaces with -, then split by -, and print only words with length > 4
string17="hey this is the sentence"
string17

#replace
string17=string17.replace(" ","-")
string17
#split
string17=string17.split("-")
string17
#len>4
for word in string17:
    if len(word)>=4:
        print(word)
# Out:
# this
# sentence

# %%
#18 18. Create a list of student names. Join them with ", ". Then replace the first name with "New Student".
students="vi","ai","n"
students

students=(",".join(students))
students

students=students.replace("vi","new student")
students
# Out:
# 'new student,ai,n'

# %%
#19 19. Take a paragraph. Split it into sentences (using .), strip each sentence, and join them with "\n- ".
para="                  Technology has changed the way we live. Today, people use smartphones to communicate, work,  learn. Online meetings save time allow teams to connect fr different cities. Digital tools also  students study more effectively. "
para
#split
para=para.split(".")
para
#strip
#para=para.strip(".")
#para
#join
para="\n".join(para)
print(para)
# Out:
#                   Technology has changed the way we live
#  Today, people use smartphones to communicate, work,  learn
#  Online meetings save time allow teams to connect fr different cities
#  Digital tools also  students study more effectively

# %%
#20 20. Take a string. Use replace(), strip(), split(), and join() together to clean and reformat it as a proper sentence.
string20="       Technology has changed the way we live        "

string20=string20.replace("live","lived")
string20


string20=string20.split(" ")
string20
string20=(" ".join(string20))
string20

string20=string20.strip(" ")
string20
# Out:
# 'Technology     has changed the way we lived'
