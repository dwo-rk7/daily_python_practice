# %%
#1. Write a program to check whether a number is positive, negative, or zero.

num1=-34

if num1>0:
    print("positive")
elif num1<0:
    print("negative")
else:
    print("zero")
# Out:
# negative

# %%
#2. Write a program to check whether a person can enter a movie theater. (Age must be 18 or above)
age=34
if age>=18:
    print("you are eligible to enter")
else:
    print("you are too young to enter mvie theater")
# Out:
# you are eligible to enter

# %%
#3. Write a program to check whether a number is divisible by 2.

num2=56

if num2%2==0:
    print("yes it is divisible by 2")
else:
    print("not dividible by 2")
# Out:
# yes it is divisible by 2

# %%
#4. Write a program to compare two numbers and print the greater number.
n1=34
n2=56

if n1>n2:
    print("the greater number is ",n1)
else:
    print("the greater number is",n2)
# Out:
# the greater number is 56

# %%
#5. Write a program to check whether a character is uppercase or lowercase.
text="r"

if text.isupper():
    print("the text is in upper case")
elif text.islower():
    print("text is in lower case")
# Out:
# text is in lower case

# %%
#6. Write a program to check whether a year is a leap year or not.
year=2000

if year%4==0 and year%100!=0 or year%4==0:
    print("the year is leap year")
else:
    print("not a leap year")
# Out:
# the year is leap year

# %%
#7. Write a program to display:
#o "Morning" if time < 12
#o "Afternoon" if time between 12 and 5
#o "Evening" otherwise

time=int(input("enter the time"))

if time >=5 or time<=12 :
    print("Morning")
elif time==12 or time<=5:
    print("Afternoon")
else:
    print("Evening")
# Out:
# enter the time 6
# Morning

# %%
#8 8. Write a program to check whether a student passed with distinction.
#o 75+ → Distinction
#o 35–74 → Pass
#o Below 35 → Fail

marks=int(input("enter the marks"))

if marks>=75:
    print("Dictinction")
elif marks<=75 and marks>=35:
    print("pass")
else:
    print("fail")
# Out:
# enter the marks 90
# Dictinction

# %% [markdown]
# MEDIUM

# %%
#1. Write a program to find the largest among three numbers.
N1=int(input("enter the number"))
N2=int(input("enter the number"))
N3=int(input("enter the number"))

if N1>N2 and N1>N3:
    print("largest number",N1)
elif N2>N1 and N2>N3:
    print("largest is ",N2)
else:
    print("largest is ",N3)
# Out:
# enter the number 45
# enter the number 67
# enter the number 89
# largest is  89

# %%
#2. Write a program to calculate electricity bill:
#o Units < 100 → ₹2/unit
#o 100–300 → ₹4/unit
#o Above 300 → ₹6/unit

unit=int(input("enter the number of units"))

if unit<100:
    print(unit*2)
elif unit>100 and unit<300:
    print(unit*4)
elif(unit>300):
    print(unit*6)
# Out:
# enter the number of units 6600
# 39600

# %%
#3. Write a program to check whether a triangle is:
#o Equilateral
#o Isosceles
#o Scalene
s1=int(input("enter the side"))
s2=int(input("enter the side"))
s3=int(input("enter the side"))

if s1==s2==s3:
    print("equilateral triangle")
elif s1==s2 and s2==s3 and s1==s3:
    print("isosceles triangle")
else:
    print("scalene triangle")
# Out:
# enter the side 67
# enter the side 78
# enter the side 54
# scalene triangle

# %%
#4. Write a program to calculate bonus:
#o Salary > 50000 → 20% bonus
#o Salary between 30000–50000 → 10% bonus
#o Otherwise → 5% bonus
salary=int(input("enter the salary"))

if salary>50000:
    print("20% bonus")
elif salary<50000 and salary>30000:
    print("10% bonus")
else:
    print("5% bonus")
# Out:
# enter the salary 60000
# 20% bonus

# %%
#5. Write a program to check login credentials using username and password.
username=input("enter your username")
password=int(input("enter the password"))
if username=="admin" and password==12345:
    print("login successful")
else:
    print("login failed")
# Out:
# enter your username asd
# enter the password 23
# login failed

# %%
#6. Write a program to check whether a number is:
#o Multiple of both 3 and 5
#o Multiple of only 3
#o Multiple of only 5
#o None

num = int(input("enter the number"))
if num%5==0 and num%3==0:
    print("divides by both ")
elif num%3==0:
    print("only divided ny 3")
elif num%5==0:
    print("only divided by 5")
else:
    print("None")
# Out:
# enter the number 5
# only divided by 5

# %%
#7 Write a program to find whether a person is:
#o Child (0–12)
#o Teenager (13–19)
#o Adult (20–59)
#o Senior Citizen (60+)

age=int(input("enter the age"))
if age>=0 and age<=12:
    print("child")
elif age>=13 and age<=19:
    print("teenager")
elif age>=20 and age<=59:
    print("Adult")
elif age>=60:
    print("senior citizen")
# Out:
# enter the age 14
# teenager

# %%
##8. Write a program to calculate ticket price:
#o Age below 5 → Free
#o 5–18 → ₹100
#o Adults → ₹200
#o Senior citizens → ₹150
age=int(input("enter the age"))
if age<5:
    print("free")
elif age>=5 and age<=18:
    print("100")
elif age>=20 and age<=59:
    print("200")
elif age>=60:
    print("150")
# Out:
# enter the age 89
# 150

# %% [markdown]
# #Hard Level (8 Questions

# %%
###
#1. Write a program to create a simple ATM system:
#o Check balance
#o Withdraw money
#o Deposit money
#o Invalid option messag


choice=int(input("enter your choice"))

if choice==1:
    print("check balance  ")
elif choice==2:
    print("withdraw money")
elif choice==3:
    print('deposit money')
else:
    print("invalid option")
# Out:
# enter your choice 3
# deposit money

# %%
#2. Write a program to calculate income tax:
#o Income below ₹250000 → No tax
#o ₹250000–₹500000 → 5%
#o ₹500000–₹1000000 → 20%
#o Above ₹1000000 → 30%

income=int(input("Enter your income"))

if income<=250000:
    print("no tax")
elif income>=250000 and income<=500000:
    print("5%")
elif income>=500000 and income<=1000000:
    print("20%")
elif income>=1000000:
    print("30%")
# Out:
# Enter your income 200000000
# 30%

# %%
# 3Write a program to determine the type of roots in a quadratic equation using discriminant.
D=int(input("Enter the valuse of quadratic root"))

if D>0:
    print("this is real and distinct roots")
elif D==0:
    print("the roots are real and equal roots")
elif D<0:
    print("the roots are complex roots")
else:
    print("invslid choice")
# Out:
# Enter the valuse of quadratic root 5
# this is real and distinct roots

# %%
#4 Write a program for a mini calculator using if elif else:
#o Addition
#o Subtraction
#o Multiplication
#o Division
Num1=int(input("enter a first number"))
Num2=int(input("enter second number")) 
C=input("Enter your choice")
if C=="addition":
    print(Num1+Num2)
elif C=="sunbtraction":
    print(Num1-Num2)
elif C=="Multiplication":
    print(Num1*Num2)
elif C=="division":
    print(Num1/Num2)
# Out:
# enter a first number 2
# enter second number 4
# Enter your choice addition
# 6

# %%
#5. Write a program to check whether three angles can form a valid triangle.
a1=int(input("enter the first angle"))
a2=int(input("enter the second angle"))
a3=int(input("enter the third angle"))
if a1+a2+a3==90:
    print("this is a valid triangle")
else:
    print("its an invalid triangle")
# Out:
# enter the first angle 30
# enter the second angle 30
# enter the third angle 20
# its an invalid triangle

# %%
#6. Write a program to determine the season based on month number.
Month=int(input("enter the month number"))

if Month==1 or Month==2 or Month==12:
    print("Winter")
elif Month==3 or Month==4 or Month==5:
    print("Spring")
elif Month==6 or Month==7 or Month==8:
    print("Summer")
elif Month ==9 or Month==10 or Month==11:
    print("rainy")
# Out:
# enter the month number 2
# Winter

# %%
#7. Write a program for an online shopping discount system:
#o Purchase above ₹5000 → 30% discount
#o ₹2000–₹5000 → 20% discount
#o Below ₹2000 → 10% discount
purchace=int(input("enter your purchace amount"))

if purchace>5000:
    print("your discount is 30%")
elif purchace>=2000 and purchace<=5000:
    print("discount is 20%")
elif purchace<=2000:
    print("discount is 10%")
# Out:
# enter your purchace amount 67
# discount is 10%

# %%
#8. Write a program to assign employee performance ratings:
#o 90+ → Excellent
#o 70–89 → Good
#o 50–69 → Average
#o Below 50 → Poor
perfo=int(input("Enter the employee performance"))

if perfo>=90:
    print("Excellent")

elif perfo>=70 and perfo<=89:
    print("Good")
elif perfo>=50 and perfo<=69:
    print("Average")
elif perfo<50:
    print("poor")
# Out:
# Enter the employee performance 45
# poor
