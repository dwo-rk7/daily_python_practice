# %%
#1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

set1={1,2,4,6,8,1,2}
print(set1)
# Out:
# {1, 2, 4, 6, 8}

# %%
#22. (Easy) Create an empty set using correct syntax and add 3 numbers using add().
set2=set()
set2.add(2)
set2.add(3)
set2.add(4)
print(set2)
# Out:
# {2, 3, 4}

# %%
#3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
s = {10, 20, 30}
s.update([40,50,60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
#4. (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.
s1 = {10, 20, 30, 40}
s1.remove(20)
print(s1)
s1.discard(20)
print(s1)
# Out:
# {40, 10, 30}
# {40, 10, 30}

# %%
#5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union,intersection, and difference.
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
U=A.union(B)
print(U)
I=A.intersection(B)
print(I)
D=A.difference(B)
B
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {3, 4, 5, 6}

# %%
#6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.
s3 = {10, 20, 30, 40}
print(25 in s3)
# Out:
# False

# %%
#7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length.
list1 =[1, 2, 2, 3, 4, 4, 5] 
print(set(list1))
set={1, 2, 3, 4, 5}
print(len(set))
# Out:
# {1, 2, 3, 4, 5}
# 5

# %%
#8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.
Numbers= set()
for i in range(5):
    numbers=input("enter the number: ")
    Numbers.update([numbers])



print(Numbers)
# Out:
# enter the number:  23
# enter the number:  34
# enter the number:  34
# enter the number:  23
# enter the number:  12
# {'12', '23', '34'}

# %%
#9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.
A = {1, 2, 3}
B = {3, 4, 5}
A.difference(B)
# Out:
# {1, 2}

# %%
#10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?
SET={23,67,87,12,11}
SET.add([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?
#       2 SET={23,67,87,12,11}
# ----> 3 SET.add([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
#11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".
age=20
if age>=18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#12. (Easy) Take a number and check if it is positive, negative, or zero using if-elif-else.
num1=34
if num1>0:
    print("postitive number")
elif num1<0:
    print("negative number")
else:
    print("zero")
# Out:
# postitive number

# %%
#13. (Medium) Take two numbers and print the larger one using if-else.
num2=23
num4=12

if num1>num2:
    print("larger number is" ,num1)
else:
    print("larger number is ",num2)
# Out:
# larger number is 34

# %%
#14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using if statement.
char=input("enter any one character")
vowel=("a","e","i","o","u")
if (char=="a" or char =="e" or char=="i" or char=="o" or char=="u"):
    print("Its a vowel")
else:
    print("it is not a vowel")
# Out:
# enter any one character u
# Its a vowel

# %%
#15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else →Fail.
marks=100
if marks>=90:
    print("A")
elif marks>=80:
    print("B")
elif marks>=70:
    print("C")
else:
    print(fail)
# Out:
# A

# %%
#16. (Hard) Take three numbers and print the largest one using if-elif-else.
num1=67
num2=100
num3=12

if num1>num2 and num1>num3:
    print("the largest number is ",num1)
elif num2>num3 and num2>num1:
    print("the largest number is ",num2)
else:
    print("the largest number is ",num3)
# Out:
# the largest number is  100

# %%
#17. (Hard) Take a number and check if it is even and greater than 50.
num=88
if num%2==0 and num>=50:
    print("It is even and greater than 50 ")
else:
    print("It is not a even number and not greater than 50")
# Out:
# It is even and greater than 50

# %%
#18. (Hard) Take username and password. If username == "admin" and password =="1234", print "Login Successful", else "Login Failed".
username="admin"
password="1234"

if (username=="admin" and password=="1234"):
    print("login sucessful")
else:
    print("login failed")
# Out:
# login sucessful

# %%
#19. (Hard) Take a year as input and check if it is a leap year (divisible by 4 but not 100, or divisible by 400).
# %4
# %100=!0
# %400

year=2034

if(year%4==0 and year%100!=0 or year%400==0):
    print("the year is leap year")
else:
    print("not a leap year")
# Out:
# not a leap year

# %%
#20. (Hard) Take three sides of a triangle and check if they can form a valid triangle (sum of any two sides > third side
a1=10
b1=10
c1=10


if a1+b1>c1:
    print("This is the valid triangle")
else:
    print("This is not the valid triangle")
# Out:
# This is the valid triangle

# %%
#1. (Hard) Take three numbers as input from the user. Print the largest number and
# also check whether all three numbers are equal or not.
n1=input("enter the number")
n2=input("enter the number")
n3=input("enter the number")

if n1>n2 and n1>n3:
    print("the largest number is ",n1)
elif n2>n3 and n2>n1:
    print("the largest number is ",n2)
else:
    print("the largest number is ",n3)

if n1==n2==n3:
    print("All the numbers are equal")
else:
    print("the numbers are not equal")
# Out:
# enter the number 25
# enter the number 67
# enter the number 100
# the largest number is  67
# the numbers are not equal

# %%
#2. (Hard) Take a year as input. Check if it is a leap year or not. (A year is leap if
# divisible by 4, but not by 100, unless also divisible by 400)

Year=int(input("enter a year"))


if(Year%4==0 and Year%100!=0 or Year%400==0):
    print("the year is leap year")
else:
    print("not a leap year")
# Out:
# enter a year 2004
# the year is leap year

# %%
#3. (Hard) Take three sides of a triangle as input. Check if they can form a valid
# triangle (sum of any two sides must be greater than the third side). If valid, also print
# the type (Equilateral, Isosceles, or Scalene).
T1=int(input("enter the side of the triangle"))
G1=int(input("enter the side of the triangle"))
F1=int(input("enter the side of the triangle"))

if T1+G1>F1:
    print("This is the valid triangle")
    if (T1==G1==F1):
        print("Equilateral")
    elif(T1==G1 or T1==F1 or G1==F1):
        print("Isosceles")
    else:
        print("Scalene")
    
    
else:
    print("This is not the valid triangle")
# Out:
# enter the side of the triangle 10
# enter the side of the triangle 20
# enter the side of the triangle 10
# This is the valid triangle
# Isosceles

# %%
#4. (Hard) Take a student's marks in 5 subjects. Calculate percentage and print grade
#according to these rules:
#• 90 or above → A+
#• 80–89 → A
#• 70–79 → B
#• 60–69 → C
#• Below 60 → Fail Also print "Passed with Distinction" if percentage >= 75.

Marks=[]
for Marks in range(5):
    Marks=int(input("Enter the student marks"))

percent=Marks/5*100
    
if Marks>=90:
    print("A")
elif Marks>=80:
    print("B")
elif Marks>=70:
    print("C")
else:
    print("fail")
# Out:
# Enter the student marks 23
# Enter the student marks 45
# Enter the student marks 65
# Enter the student marks 32
# Enter the student marks 12
# fail

# %%
#5. (Hard) Take username, password, and age as input.
#• If username == "admin" and password == "python123" and age >= 18 → Print
#"Login Successful"
#• Else if age < 18 → Print "You are too young to login"
#Else → Print "Invalid Credentials"

u_name="admin"
pass1="python123"
Age1=16


if (u_name=="admin" and pass1=="python123" and Age1>=18):
    print("login sucessful")
elif age<18:
    print("you are too young ")
else:
    print("login failed")
# Out:
# login sucessful
