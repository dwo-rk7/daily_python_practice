# %%
#1 Write a program to check if a number is positive or negative.
num1=23
if num1>0:
    print("positive number")
elif num1<0:
    print("negative number")
else:
    print("zero")
# Out:
# positive number

# %%
# 2. Take age as input. If age is greater than or equal to 18, print "You can vote".
Age=23

if Age>=18:
    print("You can vote")
else:
    print("you are too young")
# Out:
# You can vote

# %%
# 3. Take two numbers and print the larger one using if-else.
num2=45
num3=32

if num2>num3:
    print("the greatest number is",num2)
else:
    print("the greatest of two is ", num3)
# Out:
# the greatest number is 45

# %%
# 4. Check if a given number is even or odd.
num4=55

if num4%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %%
# 5. Take a character and check if it is 'A' or not.
text="b"
if ch=="A":
    print("ch is A")
else:
    print("its is not A")
# Out:
# its is not A

# %%
# 6. Take marks and print "Pass" if marks >= 40, otherwise "Fail".
marks=23

if marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# fail

# %%
# 7. Check if a number is divisible by 5.
num5=55

if num5%5==0:
    print("the number is divisible by 5")
else:
    print("not divisible by 5")
# Out:
# the number is divisible by 5

# %%
# 8 Take a number and print whether it is positive, negative, or zero.
num6=56
if num6>0:
    print("positive number")
elif num6<0:
    print("negative number")
else:
    print("zero")
# Out:
# positive number

# %%
# 9 Take three numbers and print the largest number using if-elif-else.
n1=23
n2=34
n3=56

if n1>n2 and n1>n3:
    print("largest number",n1)
elif n2>n1 and n2>n3:
    print("largest is ",n2)

else:
    print("largest is ",n3)
# Out:
# largest is  56

# %%
# 10 Take a year and check if it is a leap year (div by 4 but not 100, or divby   400).
year=2000

if year%4==0 and year%100!=0 or year%400==0:
    print("its an leap year")
else:
    print("its not a leap year")
# Out:
# its an leap year

# %%
# 11 Take a character and check if it is a vowel (a, e, i, o, u) or consonant.
ch="z"
if ch=="Aa" or ch=="Ee" or ch=="Ii" or ch=="Oo" or ch=="Uu":
    print("Its a vowel")
else:
    print("its not a vowel")
# Out:
# its not a vowel

# %%
# 12 Take salary as input. If salary > 50000 print "High", elif salary >
 # 30000 print "Medium", else print "Low".
salary=30000
if salary>50000:
    print("High")
elif salary>30000:
    print("Medium")
else:
    print("low")
# Out:
# low

# %%
# 13 Take temperature in Celsius. If > 30 print "Hot", 20-30 print "Warm",
# < 20 print "Cold".
temp=27
if temp>30:
    print("Hot")
elif temp<30 and temp>20:
    print("Warm")
else:
    print("cold")
# Out:
# Warm

# %%
# 14 Take username and password. If both correct print "Login
# Successful", else print "Login Failed".

username="admin"
password=12345

if username=="admin" and password==12345:
    print("login successful")
else:
    print("login failed")
# Out:
# login successful

# %%
# 15 Take three sides of a triangle. Check if they form a valid triangle. If
# yes, also print if it is Equilateral, Isosceles, or Scalene.
t1=34
t2=32
t3=56

if t1+t2>t3:
    print("valid triangle")
    if t1==t2==t3:
        print("equilateral")
    elif t1==t2 or t2==t3 or t3==t1:
        print("isosceles")
    else:
        print("scalene")
else:
    print("Not a valid triangle")
# Out:
# valid triangle
# scalene

# %%
# 16 Take student marks in 5 subjects. Calculate percentage and give
# grade: 90+ → A+, 80-89 → A, 70-79 → B, 60-69 → C, below 60 → Fail
mark1=int(input("enter the marks"))
mark2=int(input("enter the marks"))
mark3=int(input("enter the marks"))
mark4=int(input("enter the marks"))
mark5=int(input("enter the marks"))

total=(mark1+mark2+mark3+mark4+mark5)
print(total)
per=total/500*100
print(per)

if per>=90:
    print("A+")
elif per<90 and per>=80:
    print("A")
elif per<80 and per>=70:
    print("B")
elif per<70 and per>=60:
    print("C")
else:
    print("fail")
# Out:
# enter the marks 34
# enter the marks 56
# enter the marks 78
# enter the marks 89
# enter the marks 98
# 355
# 71.0
# B

# %%
#17 17. Take a number. Check if it is divisible by both 3 and 5. If yes print
# "FizzBuzz", by 3 print "Fizz", by 5 print "Buzz", else print the number.
num8=15

if num8%5==0 and num8%3==0:
    print("Fizzbuzz")
    if num8%3==0:
        print("Fizz")
    elif(num8%5==0):
        print("Buzz")
    
else:
    print(num8)
# Out:
# Fizzbuzz
# Fizz

# %%
#18. Take age and gender. If age >= 18 and gender is "Male" print
# "Eligible for Army", elif age >= 18 and gender "Female" print "Eligible for
# Other Services", else print "Not Eligible".

age = 21
gender= "female"

if age>=18 and gender=="male":
    print("eligible for army")
elif age>=18 and gender=="female":
    print("eligible for other services")
else:
    print("Not eligible")
# Out:
# eligible for other services

# %%
#19. Take a character. Check if it is uppercase, lowercase, digit, or special character.

text1="D"

if text1.isupper():
    print("char in upper case")
elif text1.islower():
    print("char in lower case")
elif text1.isdigit():
    print("char is the digit")
elif text1.isalpha():
    print("char is the alphabet")
else:
    print("its a special character")
# Out:
# char in upper case

# %%
#20. Take three numbers. Print them in ascending order using if-elif-else (without using sort()).

N1=34
N2=45
N3=56

if N1>N2 and N1>N3:
    print("largest number",N1)
elif N2>N1 and N2>N3:
    print("largest is ",N2)
else:
    print("largest is ",N3)

a=23
b=45
c=56

if a > b:
    a, b = b, a
if b > c:
    b, c = c, b
if a > b:
    a, b = b, a
# Out:
# largest is  56
