# %%
# 1Take a string from user and print the first 5 characters.
string1=input("Enter a string: ")
string1

first_five=string1[:5]
print(first_five)
# Out:
# Enter a string:  banana
# banan

# %%
#2 take a string and print the last 4 characters using negative slicing.

string2="This is the apple"
string2

last_four=string2[-4:]
last_four
# Out:
# 'pple'

# %%
#3 Take a string and print characters from index 2 to 8 (excluding 8).

string3="hello this is the python programming "
string3

index=string3[2:7]
index
# Out:
# 'llo t'

# %%
#4 Take a string and print every 2nd character of the string.

string4="this is the string in the python"
string4

sec_char=string4[1::2]
sec_char
# Out:
# 'hsi h tigi h yhn'

# %%
#5 5. Take a full name (e.g. "Sumit Kumar Sharma") and print only the first name and last name separately using slicing.
string5="sumit kumar sharma"
string5
f_N=string5.find(" ")
l_N=string5.rfind(" ")
slic=string5[0:f_N]
slice=string5[l_N+1:]
print("first name",slic)
print("last name",slice)
# Out:
# first name sumit
# last name sharma

# %%
#6 Take a string from user and print it in:
#* Uppercase
# Lowercase
# Title Case
# Capitalized (only first letter capital)
string6=input("Enter the string: ")
string6=string6.upper()
string6
string6=string6.lower()
string6
string6=string6.title()
string6
string6=string6.capitalize()
string6
# Out:
# Enter the string:  zxcvbnhgf
# 'Zxcvbnhgf'

# %%
#7 Take a sentence and convert it to title case. Then print the original and converted version.
sent1="This is the python practice day 2"

sent2=sent1.title()
sent2
sent1
# Out:
# 'This is the python practice day 2'

# %%
#8 8. Take a mixed case string and check if lower() and upper() methods change the string permanently or not.
string8="AbCdEfGh"
string8=string8.upper()
string8
string8=string8.lower()
string8
# Out:
# 'abcdefgh'

# %%
#9. Take a string from user and check whether it contains only alphabets (isalpha()).

# %%
str9=input("Enter the string")
str9=str9.isalpha()
str9
# Out:
# Enter the string fgfdt78
# False

# %%
#10 Take input from user and check if it is a digit only (isdigit()).
str10=input("Enter the desired string")
str10=str10.isdigit()
str10
# Out:
# Enter the desired string 765567
# True

# %%
#11 take a string and check if it is alphanumeric (isalnum()).
str11=input("Enter the string ")
str11=str11.isalnum()
str11
# Out:
# Enter the string  ftyh
# True

# %%
#12 Take a string and check if it is completely in lowercase (islower()).
str12="bhgfcTYUJHGcvbnm"
str12=str12.islower()
str12
# Out:
# False

# %%
#13 13. Take a password as input and check:
#* It should be alphanumeric
#* It should be minimum 8 characters long Print "Valid Password" or "Invalid Password".

str13=input("enter your password here:")
"valid"*(str13.isalnum()and len(str13)>=8) or"Invalid"
# Out:
# enter your password here: fgh
# 'Invalid'

# %%
#14 14. Take a string and a character from user. Find the first occurrence of that character using find().

str14="This is the string thT WE ARE GOONA USE IN THIS Problem"
char=input("enter a char over here")
str14=str14.find(char)
str14
# Out:
# enter a char over here b
# 51

# %%
#15 15. Take a string and a word. Use find() to check if the word exists. If not found, print -1.

str15="achelor's degreng cloud or software sales, or consultative account management at a B2B software company.Experience engaging an"
w=input("Enter a word you want to find")
str15=str15.find(w) 
str15
# Out:
# Enter a word you want to find vaish
# -1

# %%
#16 16. Take a sentence and find the position of the word "Python" using index().
sent3="this is the sentence for this problem in python programming"
sent3=sent3.index('python')
sent3
# Out:
# 41

# %%
#1717. Take a string. Use both find() and index() to search for a character that does not exist. Observe the difference.
str17="now this is the string"
str_f=str17.find('x')
str_f
str_i=str17.index('i')
str_i
# Out:
# 6

# %%
#18 18. Take your full name.
#* Convert it to uppercase
#* Find the position of first space
#* Print the first name and last name separately.
str18="sathis sumedh kumar"
str_18=str18.upper()
print(str_18)
str18_=str18.find(" ")
print(str18_)


str18_f=str18[0:6]
print(str18_f)
str18_l=str18[-5:]
print(str18_l)
# Out:
# SATHIS SUMEDH KUMAR
# 6
# sathis
# kumar

# %%
#19. Take a mobile number as string. Check if it is 10 digits and contains only numbers using isdigit() and len().

str19="456789098765"
str19_digit=str19.isdigit()
print(str19_digit)
str_len=len(str19)
print(str_len)
# Out:
# True
# 12

# %%
#2020. Take any string from user.
#* Print the string in reverse order using slicing
#* Convert it to title case
#•Check if the reversed string is same as original (Palindrome check)

str20=input("enter a string")
str_rev=str20[::-1]
print(str_rev)
str_tle=str20.title()
print(str_tle)

print("IS palindrome" *(str20==str_rev) or"not a palindrome")
# Out:
# enter a string cac
# cac
# Cac
# IS palindrome
