# %%
#1. Take a number as input. If the number is positive, check whether it is even or odd and print the result.
number=int(input("Enter the number"))

if number>0:
    print("Number is positive")
    if number%2==0:
        print("Its a even number")
    else:
        print("Its a odd number")
else:
    print("its not positive number")
# Out:
# Enter the number 45
# Number is positive
# Its a odd number

# %%
#2. Take age as input. If age is greater than or equal to 18, check if the person is a senior citizen (age >= 60) or adult.
age=int(input("Enter the your age"))

if age>=18:
    if age>=60:
        print("senior citizen")
    else:
        print("adult")
else:
    print("your age is less than 18 yrs")
# Out:
# Enter the your age 10
# your age is less than 18 yrs

# %%
#3. Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.
ch=input("enter the character")

if ch.isalpha():
    print("Its a alphabet")
    if ch.islower():
        print("And in lower case")
    else:
        print("And in Upper case")
else:
    print("Not a alphabet")
# Out:
# enter the character A
# Its a alphabet
# And in Upper case

# %%
#4. Take three numbers as input and print the largest number using nested if statements (without using max()).
n1=int(input("enter the number"))
n2=int(input("enter the number"))
n3=int(input("enter the number"))

if n1>n2:
    if n1>n3:
        print("the greatest number is n1: ",n1)
    else:
        print("the greatest number is n3: ",n3)
else:
    if n2>n3:
        print("the greatest number is n2: ",n2)
    else:
        print("the greatest number is n3: ",n3)
# Out:
# enter the number 12
# enter the number 344
# enter the number 99
# the greatest number is n2 344

# %%
### 5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to print "Pass with Distinction".
marks=int(input("Enter the marks"))

if marks>=40:
    print("pass")
    if marks>=75:
        print("And with distinction")
else:
    print("fail")
# Out:
# Enter the marks 45
# pass

# %%
#6. Take a number. If it is divisible by 2, check if it is also divisible by 4.
num=int(input("enter the number"))
if num%2==0:
    print("divisible by 2")
    if num%4==0:
        print("its also divisible by 4")
    else:
        ("not divisible by 4")
else:
    ("its not divisible by 2")
# Out:
# enter the number 4
# divisible by 2
# its also divisible by 4

# %%
#7. Take username and password. If username is "admin", then check if the password is correct.\
username=input("enter your username")


u_name="admin"
p_word=1234

if username==u_name:
    password=int(input("enter your password"))
    if password==p_word:
        print("Login successful")
    else:
        print("invalid password")
else:
    print("invalid username")
# Out:
# enter your username admin
# enter your password 1234
# Login successful

# %%
#8. Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.
t1=int(input("enter the side"))
t2=int(input("enter the side"))
t3=int(input("enter the side"))

if t1+t2+t3==90:
    print("Its a valid triangle")
    if t1==t2==t3:
        print("also a equilateral triangle")
    elif t1==t2 or t2==t2 or t1==t3:
        print("also a isosceles triangle")
    else:
        print("also a scalene triangle")

else:
    print("Its not a valid triangle")
# Out:
# enter the side 2
# enter the side 5
# enter the side 5
# Its not a valid triangle

# %%
#9. Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".
salary=int(input("enter the salary"))


if salary>50000:
    exp=int(input("enter the experience "))
    if exp>=5 and exp<=10:
        print("Manager")
    elif exp>=10:
        print("senior manager")
else:
    print("you do not meet salary criteria")
# Out:
# enter the salary 23456789
# enter the experience  32
# senior manager

# %%
#10.Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit,print "Digit". Else print "Special Character".
ch=input("enter the character")
if ch.isalpha():
    if ch=="AaEeIiOoUu":
        print("Vowel")
    else:
        print("consonant")
elif ch.isdigit():
    print("Digit")
else:
    print("Special character")
# Out:
# enter the character #
# Special character

# %%
#11.Take a year as input. Check if it is a leap year using nested conditions.
year=int(input("enter the year"))

if year%4==0:
    if year%100!=0 or year%400==0:
            print("its an leap year")
    else:
            print("its not a leap year")
# Out:
# enter the year 2004
# its an leap year

# %%
#12.Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm", else "Cold" using nested if.

temp=int(input("enter the tempreature"))
if temp>30:
    print("Hot")
    if temp<=30 and temp>=20:
        print("Warm")

else:
    print("Cold")
# Out:
# enter the tempreature 23
# Cold

# %%
# 13.Take three numbers. Check if all three are equal, or any two are equal using nested if.
N1=int(input("enter the number"))
N2=int(input("enter the number"))
N3=int(input("enter the number"))
if N1==N2==N3:
        print("al of them are equal")
else:
        print("None of them are equal")

if N1==N2:
    print("N1=N2")
elif N2==N3:
    print("n2=n3")
elif N1==N3:
    print("n1=n3")
# Out:
# enter the number 5
# enter the number 5
# enter the number 5
# al of them are equal
# N1=N2

# %%
#14.Take a number. If it is positive and even, print "Positive Even Number".
num=int(input("Enter the number"))

if num>0:
    if num%2==0:
        print("Positive Even number")
    else:
        print("positive number")
else:
    print("Not a positive number")
# Out:
# Enter the number 34
# Positive Even number

# %%
#15.Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.
marks1=int(input("enter the marks"))
marks2=int(input("enter the marks"))
marks3=int(input("enter the marks"))
marks4=int(input("enter the marks"))
marks5=int(input("enter the marks"))

Total=marks1+marks2+marks3+marks4+marks5
avg=Total/5*100
if avg>=60:
    if marks1>40 and marks2>40 and marks3>40 and marks4>40 and marks5>40:
        print("all subject marks above 40")
    else:
        print("some subject have poor performance")
# Out:
# enter the marks 78
# enter the marks 87
# enter the marks 78
# enter the marks 87
# enter the marks 89
# all subject marks above 40

# %%
#16.Take username, password, and age. If username and password are correct and
#age >= 18, print "Login Successful". Else if age < 18, print age restriction message.
Age=int(input("Enter the your age"))
Username=input("enter your username")
Password=int(input("enter your password"))

U_name="admin"
P_word=1234
A_Age=23

if Username==U_name:
    if Password==P_word:
        if Age==A_Age:
            print("login sucessful")
        else:
            print("Age below 18")
# Out:
# Enter the your age 23
# enter your username 34
# enter your password 23

# %%
#17.Take a number. Check if it is divisible by both 3 and 5 using nested if.
Nnum=int(input("enter the number"))
if Nnum%3==0:
    print("divisible by 3")
    if Nnum%5==0:
        print("its also divisible by 5")
    else:
        ("not divisible by 5")
else:
    ("its not divisible by 3")
# Out:
# enter the number 33
# divisible by 3

# %%
#18.Take three sides of a triangle. Check if valid, then check if it is a right-angled triangle using Pythagoras theorem.
s1=int(input("enter the side"))
s2=int(input("enter the side"))
s3=int(input("enter the side"))

if s1+s2>s3 or ss1+s3>s2:
    print("Its a valid triangle")
    if s1*s1+s2*s2==s3*s3:
        print("its a right angle triangle ")
    else:
        print("not a right angle triangle")

else:
    print("not a valid triangle")
# Out:
# enter the side 34
# enter the side 56
# enter the side 23
# Its a valid triangle
# not a ringht angle triangle

# %%
#19.Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent,Good, Average, etc.)


grade=input("enter your grade")

if grade=='A':
    print("Excellent")
elif grade=='B':
    print("Good")
elif grade=='C':
    print("Average")
elif garde=='D':
    print("Need improvement")
else:
    print("fail")
# Out:
# enter your grade A
# Excellent

# %%
#20.Take income. If income > 1000000, check tax slab. If income between 500000- 1000000, different slab. Else print "Low Income".
income=int(input("enter your income"))
if income>1000000:
    print("30%")
elif income>=500000 and income<=1000000:
    print("10%")
else:
    print("Low income")
# Out:
# enter your income 123456
# Low income

# %%
#1. (Hard) Take three sides of a triangle as input. First check if they can form a valid
# triangle (sum of any two sides > third side). If valid, then further check and print
# whether the triangle is Equilateral, Isosceles, or Scalene.
S1=int(input("enter the side"))
S2=int(input("enter the side"))
S3=int(input("enter the side"))

if S1+S2>S3 or S1+S3>S2:
    print("Its a valid triangle")
    if S1==S2==S3:
        print("also a equilateral triangle")
    elif S1==S2 or S2==S2 or S1==S3:
        print("also a isosceles triangle")
    else:
        print("also a scalene triangle")
    

else:
    print("not a valid triangle")
# Out:
# enter the side 12
# enter the side 23
# enter the side 32
# Its a valid triangle
# also a isosceles triangle

# %%
#2. (Hard) Take a student's marks in 5 subjects. Calculate the average. If average >=
# 60, then check if all individual subjects are above 40. If yes, print "Pass with Good
# Performance", else print "Pass but Weak in some subjects". If average < 60, print"Fail".
marks1=int(input("enter the marks"))
marks2=int(input("enter the marks"))
marks3=int(input("enter the marks"))
marks4=int(input("enter the marks"))
marks5=int(input("enter the marks"))

Total=marks1+marks2+marks3+marks4+marks5
avg=Totla/5*100

if avg>=60:
    if marks1>40 and mark2>40 and mark3>40 and mark4>40 and mark5>40:
        print("pass with good performance")

    else:
        print("pass but weak in some subjests")
else:
    if avg<60:
        print("fail")
# Out:
# enter the marks 2
# enter the marks 3
# enter the marks 43
# enter the marks 345
# enter the marks 443
# pass but weak in some subjests

# %%
## 3. (Hard) Take username, password, and age as input.
#• If username == "admin" and password == "python123" and age >= 18, print
#"Login Successful".
#• Else if age < 18, print "You are too young to login".
#• Else if username is wrong, print "Invalid Username".
#• Else print "Invalid Password".


Username=input("enter your username")
Password=input("enter your password")
Age=int(input("Enter the your age"))
U_name="admin"
P_word="python123"


if Username==U_name:
    if Password==P_word:
        if Age>=18:
            print("login sucessful")
        elif Age<18:
            print("too young to login")
    else:
         print("Invalid password")
else:
    print("Inavlid Username")
# Out:
# enter your username 23
# enter your password 234
# Enter the your age 45
# Inavlid Username

# %%
#4. (Hard) Take a number as input. Check if the number is positive. If positive, check
#if it is divisible by both 3 and 5. If yes, print "FizzBuzz". If only divisible by 3 print
#"Fizz", only by 5 print "Buzz". If negative, print "Negative Number".

Nnum=int(input("enter the number"))
if Nnum>0:
    if Nnum%3==0 and Nnum%5==0:
        print("fizzBuzz")
    elif Nnum%3==0:
        print("Fizz")
    elif Nnum%5==0:
        print("Buzz")
           
else:
    print("Negative number")
# Out:
# enter the number 56

# %%
#5. (Hard) Take three numbers. First check if all three are equal. If not, check which
#one is the largest. Also check if the largest number is even or odd and print all
#information accordingly.
n4=int(input("enter the number"))
n5=int(input("enter the number"))
n6=int(input("enter the number"))

if n4==n5==n6:
    print("all the numbers are equal")
else:
    if n4>n5:
        if n4>n6:
            print("the greatest number is n1: ",n4)
        else:
            print("the greatest number is n3: ",n6)
    elif:
        if n5>n6:
            print("the greatest number is n2: ",n5)
        else:
            print("the greatest number is n3: ",n6)
# Out:
# enter the number 56
# enter the number 89
# enter the number 98
# the greatest number is n3:  98
